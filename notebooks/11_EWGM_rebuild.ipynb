# %%
import numpy as np
import pandas as pd
import optuna
from functools import partial


# =====================================================
# Utility Functions
# =====================================================

def build_month_codes():
    """Create a mapping from month abbreviations to numeric values."""
    return {m: i for i, m in enumerate(
        ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
         'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], start=1)}


def split_test_id_column(df: pd.DataFrame) -> pd.DataFrame:
    """Parse the ID column into month text and sector components."""
    parts = df['id'].str.split('_', expand=True)
    df['month_text'], df['sector'] = parts[0], parts[1]
    return df


def add_time_and_sector_fields(df: pd.DataFrame, month_codes: dict) -> pd.DataFrame:
    """Add parsed year, month, time index, and sector_id to dataframe."""
    if 'sector' in df.columns:
        df['sector_id'] = df['sector'].str[7:].astype(int)

    if 'month' in df.columns:  # test data
        df['year'] = df['month'].str[:4].astype(int)
        df['month'] = df['month'].str[5:].map(month_codes)
    else:  # train data
        df['year'] = df['month_text'].str[:4].astype(int)
        df['month'] = df['month_text'].str[5:].map(month_codes)

    df['time'] = (df['year'] - 2019) * 12 + df['month'] - 1
    return df


def load_competition_data():
    """Load competition training and test datasets."""
    path = '/Users/nikola/Python/KaggleCompetition/data'
    train = pd.read_csv(f'{path}/train/new_house_transactions.csv')
    test = pd.read_csv(f'{path}/test.csv')
    return train, test


# =====================================================
# Data Transformation
# =====================================================

def build_amount_matrix(train: pd.DataFrame, month_codes: dict) -> pd.DataFrame:
    """Pivot training data into [time x sector_id] transaction matrix."""
    train = add_time_and_sector_fields(train.copy(), month_codes)
    pivot = train.pivot_table(
        index='time', columns='sector_id',
        values='amount_new_house_transactions', fill_value=0
    )

    # Ensure all 96 sectors are present
    all_sectors = np.arange(1, 97)
    pivot = pivot.reindex(columns=all_sectors, fill_value=0)

    return pivot


# =====================================================
# Modeling Helpers
# =====================================================

def compute_december_multipliers(a_tr, eps=1e-9, min_dec_obs=1, clip_low=0.8, clip_high=1.5):
    """Compute sector-level December multipliers from training data."""
    is_dec = (a_tr.index % 12 == 11)
    dec_means = a_tr[is_dec].mean()
    nondec_means = a_tr[~is_dec].mean()
    dec_counts = a_tr[is_dec].count()

    raw_mult = dec_means / (nondec_means + eps)
    overall_mult = float(dec_means.mean() / (nondec_means.mean() + eps))

    raw_mult = raw_mult.where(dec_counts >= min_dec_obs, overall_mult)
    raw_mult = raw_mult.replace([np.inf, -np.inf], 1.0).fillna(1.0)
    return raw_mult.clip(clip_low, clip_high).to_dict()


def apply_december_bump_row(pred_row: pd.Series, sector_to_mult: dict) -> pd.Series:
    """Apply December adjustment to a prediction row."""
    return pred_row.multiply(pd.Series(sector_to_mult)).fillna(pred_row)


def ewgm_per_sector(a_tr, sector, n_lags, alpha):
    """Exponential weighted geometric mean for one sector."""
    recent = a_tr[sector].tail(n_lags).values
    if len(recent) < n_lags or (recent <= 0).all():
        return 0.0

    weights = np.array([alpha**(n_lags - 1 - i) for i in range(n_lags)])
    weights /= weights.sum()

    mask = recent > 0
    if not mask.any():
        return 0.0

    log_vals = np.log(recent[mask] + 1e-12)
    pos_w = weights[mask] / weights[mask].sum()
    return float(np.exp(np.sum(pos_w * log_vals)))


def predict_one_step(a_hist, n_lags, alpha):
    """Predict next-step values for all sectors."""
    return pd.Series({
        sector: ewgm_per_sector(a_hist, sector, n_lags, alpha)
        if a_hist[sector].tail(n_lags).min() > 0 else 0.0
        for sector in a_hist.columns
    })


def evaluate_params(a_tr_full, n_lags, alpha, t2, clip_low, clip_high, val_len=6):
    """Evaluate parameters via rolling-origin backtest."""
    times = a_tr_full.index
    if len(times) < max(n_lags + 1, t2 + 1) + val_len:
        return 1e12

    rmses = []
    for t in times[-val_len:]:
        a_hist = a_tr_full.loc[a_tr_full.index < t]
        if len(a_hist) < max(n_lags, t2):
            continue

        y_true = a_tr_full.loc[t]
        y_pred = predict_one_step(a_hist, n_lags, alpha)

        if t % 12 == 11:  # December bump
            mult = compute_december_multipliers(a_hist, clip_low=clip_low, clip_high=clip_high)
            y_pred = apply_december_bump_row(y_pred, mult)

        rmses.append(np.sqrt(np.mean((y_pred - y_true) ** 2)))

    return float(np.mean(rmses)) if rmses else 1e12


def predict_horizon(a_tr, n_lags, alpha, t2):
    """Forecast horizon [67..78]."""
    idx = np.arange(67, 79)
    preds = pd.DataFrame(index=idx, columns=a_tr.columns, dtype=float)

    for sector in a_tr.columns:
        if (a_tr[sector].tail(t2).min() == 0) or (a_tr[sector].sum() == 0):
            preds[sector] = 0.0
        else:
            preds[sector] = ewgm_per_sector(a_tr, sector, n_lags, alpha)

    preds.index.name = 'time'
    return preds


# =====================================================
# Submission
# =====================================================

def build_submission_df(a_pred, test_raw, month_codes):
    """Format predictions into competition submission file."""
    test = add_time_and_sector_fields(split_test_id_column(test_raw.copy()), month_codes)
    lookup = a_pred.stack().rename('pred').reset_index().rename(columns={'level_1': 'sector_id'})
    merged = test.merge(lookup, on=['time', 'sector_id'], how='left')
    merged['pred'] = merged['pred'].fillna(0.0)

    return merged[['id', 'pred']].rename(columns={'pred': 'new_house_transaction_amount'})


def generate_submission_with_december_bump(n_lags=6, alpha=0.5, t2=6, clip_low=0.85, clip_high=1.4):
    """End-to-end pipeline for submission with December bump."""
    month_codes = build_month_codes()
    train, test = load_competition_data()
    a_tr = build_amount_matrix(train, month_codes)
    a_pred = predict_horizon(a_tr, n_lags, alpha, t2)

    # Apply December bump
    mult = compute_december_multipliers(a_tr, clip_low=clip_low, clip_high=clip_high)
    for t in a_pred.index[a_pred.index % 12 == 11]:
        a_pred.loc[t] = apply_december_bump_row(a_pred.loc[t], mult)

    sub = build_submission_df(a_pred, test, month_codes)
    sub.to_csv('/Users/nikola/Python/KaggleCompetition/output/11_EWGM/submission.csv', index=False)
    return a_tr, a_pred, sub


# =====================================================
# Optuna Optimization
# =====================================================

def optuna_objective(trial, a_tr):
    """Objective for Optuna hyperparameter tuning."""
    n_lags = trial.suggest_int('n_lags', 3, 12)
    alpha = trial.suggest_float('alpha', 0.20, 0.95)
    t2 = trial.suggest_int('t2', 3, 9)
    clip_low = trial.suggest_float('clip_low', 0.70, 0.95)
    clip_high = trial.suggest_float('clip_high', 1.10, 1.80)

    if clip_low >= clip_high:
        clip_low = max(0.70, clip_high - 0.05)

    return evaluate_params(a_tr, n_lags, alpha, t2, clip_low, clip_high)


def run_optuna_search(a_tr, n_trials=1000, seed=1337):
    """Run Optuna search and return the study."""
    study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=seed))
    study.optimize(partial(optuna_objective, a_tr=a_tr), n_trials=n_trials, show_progress_bar=False)
    return study


# =====================================================
# Main
# =====================================================

def main():
    month_codes = build_month_codes()
    train, _ = load_competition_data()
    a_tr = build_amount_matrix(train, month_codes)

    # Run Optuna search
    study = run_optuna_search(a_tr, n_trials=512, seed=1337)
    best = study.best_params

    # Generate submission
    generate_submission_with_december_bump(**best)
    print("Best parameters:", best)
    print("Submission saved to /Users/nikola/Python/KaggleCompetition/output/11_EWGM")


if __name__ == "__main__":
    main()
# Out:
# [I 2025-09-30 02:04:45,834] A new study created in memory with name: no-name-45c1f779-6ad3-472f-a7ba-9844de23fe53
# [I 2025-09-30 02:04:45,855] Trial 0 finished with value: 21383.972104866807 and parameters: {'n_lags': 5, 'alpha': 0.31901297911584925, 't2': 4, 'clip_low': 0.8148292218036416, 'clip_high': 1.3247003783641171}. Best is trial 0 with value: 21383.972104866807.
# [I 2025-09-30 02:04:45,872] Trial 1 finished with value: 21231.50264119316 and parameters: {'n_lags': 8, 'alpha': 0.3964571941738585, 't2': 9, 'clip_low': 0.8832036381726205, 'clip_high': 1.1806919586782048}. Best is trial 1 with value: 21231.50264119316.
# [I 2025-09-30 02:04:45,888] Trial 2 finished with value: 21112.848609130506 and parameters: {'n_lags': 6, 'alpha': 0.6713758846547837, 't2': 3, 'clip_low': 0.9458871512859103, 'clip_high': 1.4102574080515897}. Best is trial 2 with value: 21112.848609130506.
# [I 2025-09-30 02:04:45,904] Trial 3 finished with value: 21122.422935786373 and parameters: {'n_lags': 10, 'alpha': 0.79558893184369, 't2': 5, 'clip_low': 0.8040259848927495, 'clip_high': 1.508980689677225}. Best is trial 2 with value: 21112.848609130506.
# [I 2025-09-30 02:04:45,920] Trial 4 finished with value: 21321.324163223555 and parameters: {'n_lags': 10, 'alpha': 0.3408563040698117, 't2': 5, 'clip_low': 0.8675547145400585, 'clip_high': 1.4497537829604088}. Best is trial 2 with value: 21112.848609130506.
# [I 2025-09-30 02:04:45,935] Trial 5 finished with value: 21375.939294205604 and parameters: {'n_lags': 4, 'alpha': 0.5098559760684942, 't2': 4, 'clip_low': 0.8329248508967592, 'clip_high': 1.682659492147588}. Best is trial 2 with value: 21112.848609130506.
# [I 2025-09-30 02:04:45,951] Trial 6 finished with value: 21981.152937868577 and parameters: {'n_lags': 4, 'alpha': 0.9180194177534455, 't2': 5, 'clip_low': 0.8260017597903593, 'clip_high': 1.4573296627781631}. Best is trial 2 with value: 21112.848609130506.
# [I 2025-09-30 02:04:45,966] Trial 7 finished with value: 21323.23594847368 and parameters: {'n_lags': 3, 'alpha': 0.7487675515007182, 't2': 9, 'clip_low': 0.7407193833174418, 'clip_high': 1.1886443457835865}. Best is trial 2 with value: 21112.848609130506.
# [I 2025-09-30 02:04:45,982] Trial 8 finished with value: 21131.555855911076 and parameters: {'n_lags': 6, 'alpha': 0.719914583150848, 't2': 3, 'clip_low': 0.7923072655648714, 'clip_high': 1.141075527906079}. Best is trial 2 with value: 21112.848609130506.
# [I 2025-09-30 02:04:45,998] Trial 9 finished with value: 21150.289634258897 and parameters: {'n_lags': 10, 'alpha': 0.4623269095249864, 't2': 7, 'clip_low': 0.8228072693164696, 'clip_high': 1.7810106309081644}. Best is trial 2 with value: 21112.848609130506.
# [I 2025-09-30 02:04:46,015] Trial 10 finished with value: 21093.690894088948 and parameters: {'n_lags': 7, 'alpha': 0.6178062518067623, 't2': 7, 'clip_low': 0.9364244149871879, 'clip_high': 1.5780022577297164}. Best is trial 10 with value: 21093.690894088948.
# [I 2025-09-30 02:04:46,033] Trial 11 finished with value: 21094.005759207124 and parameters: {'n_lags': 7, 'alpha': 0.6136437470111018, 't2': 7, 'clip_low': 0.9480450968302885, 'clip_high': 1.5953497173720117}. Best is trial 10 with value: 21093.690894088948.
# [I 2025-09-30 02:04:46,054] Trial 12 finished with value: 21096.721246042234 and parameters: {'n_lags': 7, 'alpha': 0.5926902717110654, 't2': 7, 'clip_low': 0.9442375014368745, 'clip_high': 1.6138738076887598}. Best is trial 10 with value: 21093.690894088948.
# [I 2025-09-30 02:04:46,080] Trial 13 finished with value: 21700.647970117716 and parameters: {'n_lags': 8, 'alpha': 0.20563828697295955, 't2': 7, 'clip_low': 0.9050039798962632, 'clip_high': 1.6018220250780288}. Best is trial 10 with value: 21093.690894088948.
# [I 2025-09-30 02:04:46,102] Trial 14 finished with value: 21080.031173804742 and parameters: {'n_lags': 8, 'alpha': 0.5998900635155954, 't2': 8, 'clip_low': 0.9115106298560189, 'clip_high': 1.7977978030395279}. Best is trial 14 with value: 21080.031173804742.
# [I 2025-09-30 02:04:46,121] Trial 15 finished with value: 21232.90784785687 and parameters: {'n_lags': 12, 'alpha': 0.8557764896645352, 't2': 8, 'clip_low': 0.9030475037432403, 'clip_high': 1.7839315361211785}. Best is trial 14 with value: 21080.031173804742.
# [I 2025-09-30 02:04:46,141] Trial 16 finished with value: 21115.30283828125 and parameters: {'n_lags': 9, 'alpha': 0.5024649093002029, 't2': 8, 'clip_low': 0.9075350661719883, 'clip_high': 1.6992892275498137}. Best is trial 14 with value: 21080.031173804742.
# [I 2025-09-30 02:04:46,163] Trial 17 finished with value: 21057.60789225256 and parameters: {'n_lags': 12, 'alpha': 0.6345841338652976, 't2': 8, 'clip_low': 0.8667247760838278, 'clip_high': 1.302582240445358}. Best is trial 17 with value: 21057.60789225256.
# [I 2025-09-30 02:04:46,183] Trial 18 finished with value: 21052.337949481866 and parameters: {'n_lags': 12, 'alpha': 0.6611299409108008, 't2': 8, 'clip_low': 0.859263973353936, 'clip_high': 1.281335958091224}. Best is trial 18 with value: 21052.337949481866.
# [I 2025-09-30 02:04:46,203] Trial 19 finished with value: 21147.279387094106 and parameters: {'n_lags': 12, 'alpha': 0.8168588720024443, 't2': 6, 'clip_low': 0.8550487378918726, 'clip_high': 1.2762632425262985}. Best is trial 18 with value: 21052.337949481866.
# [I 2025-09-30 02:04:46,223] Trial 20 finished with value: 21056.667830971684 and parameters: {'n_lags': 11, 'alpha': 0.7012970996032379, 't2': 9, 'clip_low': 0.7777426803673517, 'clip_high': 1.2941629919145914}. Best is trial 18 with value: 21052.337949481866.
# [I 2025-09-30 02:04:46,243] Trial 21 finished with value: 21053.326633853303 and parameters: {'n_lags': 11, 'alpha': 0.6906429938055422, 't2': 9, 'clip_low': 0.7557973936069526, 'clip_high': 1.3065307418263212}. Best is trial 18 with value: 21052.337949481866.
# [I 2025-09-30 02:04:46,264] Trial 22 finished with value: 21061.9153188065 and parameters: {'n_lags': 11, 'alpha': 0.7137294455341526, 't2': 9, 'clip_low': 0.7699401433176297, 'clip_high': 1.3557483520621194}. Best is trial 18 with value: 21052.337949481866.
# [I 2025-09-30 02:04:46,284] Trial 23 finished with value: 21051.794198788033 and parameters: {'n_lags': 11, 'alpha': 0.6842188483019686, 't2': 9, 'clip_low': 0.7156395110040743, 'clip_high': 1.2457568923572153}. Best is trial 23 with value: 21051.794198788033.
# [I 2025-09-30 02:04:46,304] Trial 24 finished with value: 21091.89831839214 and parameters: {'n_lags': 11, 'alpha': 0.5338638736365147, 't2': 9, 'clip_low': 0.7071604236707135, 'clip_high': 1.2504350746233586}. Best is trial 23 with value: 21051.794198788033.
# [I 2025-09-30 02:04:46,325] Trial 25 finished with value: 21232.539275834002 and parameters: {'n_lags': 9, 'alpha': 0.9071249596737114, 't2': 8, 'clip_low': 0.7102524441536533, 'clip_high': 1.22489863688503}. Best is trial 23 with value: 21051.794198788033.
# [I 2025-09-30 02:04:46,346] Trial 26 finished with value: 21124.621502004917 and parameters: {'n_lags': 11, 'alpha': 0.7834255624200636, 't2': 9, 'clip_low': 0.7380923729431235, 'clip_high': 1.1053528478937777}. Best is trial 23 with value: 21051.794198788033.
# [I 2025-09-30 02:04:46,374] Trial 27 finished with value: 21225.886840907584 and parameters: {'n_lags': 12, 'alpha': 0.8531311963094229, 't2': 8, 'clip_low': 0.7334349677534651, 'clip_high': 1.37322132165379}. Best is trial 23 with value: 21051.794198788033.
# [I 2025-09-30 02:04:46,395] Trial 28 finished with value: 21048.963548614516 and parameters: {'n_lags': 10, 'alpha': 0.6746500750564616, 't2': 6, 'clip_low': 0.7589697753583035, 'clip_high': 1.2076527752079695}. Best is trial 28 with value: 21048.963548614516.
# [I 2025-09-30 02:04:46,414] Trial 29 finished with value: 21177.53118082114 and parameters: {'n_lags': 9, 'alpha': 0.4372967209952784, 't2': 6, 'clip_low': 0.7172963864083752, 'clip_high': 1.2046529970786806}. Best is trial 28 with value: 21048.963548614516.
# [I 2025-09-30 02:04:46,434] Trial 30 finished with value: 21079.08700779227 and parameters: {'n_lags': 10, 'alpha': 0.5550149162666242, 't2': 6, 'clip_low': 0.8432894866963501, 'clip_high': 1.1295061463082416}. Best is trial 28 with value: 21048.963548614516.
# [I 2025-09-30 02:04:46,453] Trial 31 finished with value: 21049.065941851004 and parameters: {'n_lags': 11, 'alpha': 0.6621855805468223, 't2': 9, 'clip_low': 0.76733735966533, 'clip_high': 1.3327540307189527}. Best is trial 28 with value: 21048.963548614516.
# [I 2025-09-30 02:04:46,472] Trial 32 finished with value: 21054.225067008767 and parameters: {'n_lags': 12, 'alpha': 0.6492910191384065, 't2': 8, 'clip_low': 0.7557222119876925, 'clip_high': 1.3522720223034619}. Best is trial 28 with value: 21048.963548614516.
# [I 2025-09-30 02:04:46,491] Trial 33 finished with value: 21074.132468744316 and parameters: {'n_lags': 10, 'alpha': 0.7441234219006617, 't2': 9, 'clip_low': 0.8036553889335374, 'clip_high': 1.2382358617895055}. Best is trial 28 with value: 21048.963548614516.
# [I 2025-09-30 02:04:46,509] Trial 34 finished with value: 21050.417443139104 and parameters: {'n_lags': 11, 'alpha': 0.6765713870333709, 't2': 6, 'clip_low': 0.7272230588204063, 'clip_high': 1.1757904486734714}. Best is trial 28 with value: 21048.963548614516.
# [I 2025-09-30 02:04:46,528] Trial 35 finished with value: 21064.22418934078 and parameters: {'n_lags': 9, 'alpha': 0.7531303307897286, 't2': 5, 'clip_low': 0.7212730735943851, 'clip_high': 1.1683862673118506}. Best is trial 28 with value: 21048.963548614516.
# [I 2025-09-30 02:04:46,547] Trial 36 finished with value: 21072.27923639433 and parameters: {'n_lags': 11, 'alpha': 0.56805491980048, 't2': 6, 'clip_low': 0.7543840740804129, 'clip_high': 1.4069826061171}. Best is trial 28 with value: 21048.963548614516.
# [I 2025-09-30 02:04:46,566] Trial 37 finished with value: 21048.323105378575 and parameters: {'n_lags': 10, 'alpha': 0.6624955639107405, 't2': 5, 'clip_low': 0.700554734706149, 'clip_high': 1.1681535268286978}. Best is trial 37 with value: 21048.323105378575.
# [I 2025-09-30 02:04:46,585] Trial 38 finished with value: 21155.81966841245 and parameters: {'n_lags': 10, 'alpha': 0.8196868223166327, 't2': 4, 'clip_low': 0.7000519862608406, 'clip_high': 1.1600340730732537}. Best is trial 37 with value: 21048.323105378575.
# [I 2025-09-30 02:04:46,603] Trial 39 finished with value: 21047.48285132599 and parameters: {'n_lags': 9, 'alpha': 0.6510372619244491, 't2': 5, 'clip_low': 0.7798716865778679, 'clip_high': 1.1094103489545892}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,623] Trial 40 finished with value: 21270.118005395794 and parameters: {'n_lags': 9, 'alpha': 0.36981313833992313, 't2': 5, 'clip_low': 0.7796894648385345, 'clip_high': 1.1345325038974525}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,645] Trial 41 finished with value: 21048.313366938473 and parameters: {'n_lags': 10, 'alpha': 0.6595479046729051, 't2': 5, 'clip_low': 0.7272510776840949, 'clip_high': 1.1050191123873614}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,665] Trial 42 finished with value: 21048.927644496074 and parameters: {'n_lags': 10, 'alpha': 0.6464386349138724, 't2': 5, 'clip_low': 0.7483350844761906, 'clip_high': 1.1073189349979793}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,686] Trial 43 finished with value: 21114.94489912114 and parameters: {'n_lags': 10, 'alpha': 0.5017848240915392, 't2': 5, 'clip_low': 0.7496926453951258, 'clip_high': 1.1019351074231931}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,706] Trial 44 finished with value: 21076.138420518004 and parameters: {'n_lags': 8, 'alpha': 0.6288671766971146, 't2': 4, 'clip_low': 0.7427423954230529, 'clip_high': 1.1966511544451301}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,726] Trial 45 finished with value: 21057.186068880186 and parameters: {'n_lags': 9, 'alpha': 0.7365530635465616, 't2': 4, 'clip_low': 0.7961960078374994, 'clip_high': 1.1383585801347074}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,746] Trial 46 finished with value: 21066.089720696848 and parameters: {'n_lags': 10, 'alpha': 0.581508890227346, 't2': 4, 'clip_low': 0.7300236311941053, 'clip_high': 1.1242001350476238}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,767] Trial 47 finished with value: 21125.584035186956 and parameters: {'n_lags': 8, 'alpha': 0.7815168696301408, 't2': 5, 'clip_low': 0.7845193909140535, 'clip_high': 1.2126937343064597}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,787] Trial 48 finished with value: 21076.87105198086 and parameters: {'n_lags': 10, 'alpha': 0.5591006287811717, 't2': 3, 'clip_low': 0.7679171611812843, 'clip_high': 1.1586972191280065}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,806] Trial 49 finished with value: 21104.222293416697 and parameters: {'n_lags': 6, 'alpha': 0.613091134454798, 't2': 5, 'clip_low': 0.7437834978258067, 'clip_high': 1.1010263322590619}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,825] Trial 50 finished with value: 21457.44228613727 and parameters: {'n_lags': 9, 'alpha': 0.28070247907600354, 't2': 5, 'clip_low': 0.8142416201387228, 'clip_high': 1.5066794930923517}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,844] Trial 51 finished with value: 21048.362494358586 and parameters: {'n_lags': 10, 'alpha': 0.6564531762574339, 't2': 6, 'clip_low': 0.768387276136746, 'clip_high': 1.1837826443421675}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,863] Trial 52 finished with value: 21048.631395139106 and parameters: {'n_lags': 10, 'alpha': 0.6503932605138673, 't2': 6, 'clip_low': 0.7619370063306287, 'clip_high': 1.195483687078156}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,882] Trial 53 finished with value: 21047.89551398799 and parameters: {'n_lags': 9, 'alpha': 0.6477839252950247, 't2': 5, 'clip_low': 0.7913801136371026, 'clip_high': 1.159281421698119}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,901] Trial 54 finished with value: 21089.993057666998 and parameters: {'n_lags': 8, 'alpha': 0.7171821562467823, 't2': 6, 'clip_low': 0.7937382168247817, 'clip_high': 1.1800001923023875}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,920] Trial 55 finished with value: 21061.237888680687 and parameters: {'n_lags': 9, 'alpha': 0.5958674338282233, 't2': 5, 'clip_low': 0.815603098490749, 'clip_high': 1.2604153462634236}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,939] Trial 56 finished with value: 21267.45147611088 and parameters: {'n_lags': 3, 'alpha': 0.6275151656953828, 't2': 6, 'clip_low': 0.7861764807348435, 'clip_high': 1.1528577924265992}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,958] Trial 57 finished with value: 21091.803922171075 and parameters: {'n_lags': 9, 'alpha': 0.535475937488863, 't2': 5, 'clip_low': 0.7701628466431674, 'clip_high': 1.1926087228084477}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,977] Trial 58 finished with value: 21101.429548137297 and parameters: {'n_lags': 7, 'alpha': 0.6990506932166174, 't2': 7, 'clip_low': 0.7025139063769513, 'clip_high': 1.1469245082012076}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:46,995] Trial 59 finished with value: 21539.655552387565 and parameters: {'n_lags': 5, 'alpha': 0.7641615904549439, 't2': 4, 'clip_low': 0.800885140743408, 'clip_high': 1.1812732052302009}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:47,014] Trial 60 finished with value: 21093.068704371497 and parameters: {'n_lags': 8, 'alpha': 0.7248347419777381, 't2': 6, 'clip_low': 0.7757199896687067, 'clip_high': 1.2338185918361466}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:47,033] Trial 61 finished with value: 21048.353782749047 and parameters: {'n_lags': 10, 'alpha': 0.6568089182849822, 't2': 5, 'clip_low': 0.7630581504643674, 'clip_high': 1.1174792972802232}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:47,052] Trial 62 finished with value: 21060.984442190656 and parameters: {'n_lags': 10, 'alpha': 0.594339851280419, 't2': 5, 'clip_low': 0.7631018846932217, 'clip_high': 1.12879710649417}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:47,071] Trial 63 finished with value: 21049.136586790886 and parameters: {'n_lags': 10, 'alpha': 0.644202400762861, 't2': 5, 'clip_low': 0.8118125818465508, 'clip_high': 1.123347651629296}. Best is trial 39 with value: 21047.48285132599.
# [I 2025-09-30 02:04:47,090] Trial 64 finished with value: 21046.514150348215 and parameters: {'n_lags': 9, 'alpha': 0.6867385000020392, 't2': 5, 'clip_low': 0.8337149026246702, 'clip_high': 1.1610386965200645}. Best is trial 64 with value: 21046.514150348215.
# [I 2025-09-30 02:04:47,109] Trial 65 finished with value: 21046.1980839348 and parameters: {'n_lags': 9, 'alpha': 0.6805392194855965, 't2': 4, 'clip_low': 0.8350972709469058, 'clip_high': 1.1572425691428319}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,128] Trial 66 finished with value: 21046.649007762022 and parameters: {'n_lags': 9, 'alpha': 0.6885818770133085, 't2': 4, 'clip_low': 0.8300953439622957, 'clip_high': 1.1567447698204896}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,146] Trial 67 finished with value: 21085.161455674654 and parameters: {'n_lags': 8, 'alpha': 0.703198963371237, 't2': 3, 'clip_low': 0.8353930704781445, 'clip_high': 1.2689033782583767}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,165] Trial 68 finished with value: 21046.853485629956 and parameters: {'n_lags': 9, 'alpha': 0.6909872425315132, 't2': 4, 'clip_low': 0.842550731065147, 'clip_high': 1.2195816454437045}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,185] Trial 69 finished with value: 21150.3986834759 and parameters: {'n_lags': 7, 'alpha': 0.8100471523312573, 't2': 4, 'clip_low': 0.8465185355626774, 'clip_high': 1.2192608152898308}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,210] Trial 70 finished with value: 21072.036670941776 and parameters: {'n_lags': 9, 'alpha': 0.7677919045266131, 't2': 4, 'clip_low': 0.8799589220698676, 'clip_high': 1.148155770849693}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,229] Trial 71 finished with value: 21047.680418502878 and parameters: {'n_lags': 9, 'alpha': 0.6983332832146715, 't2': 4, 'clip_low': 0.8351045332247188, 'clip_high': 1.160961508739946}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,248] Trial 72 finished with value: 21054.568791127036 and parameters: {'n_lags': 9, 'alpha': 0.7289504481040243, 't2': 3, 'clip_low': 0.8272357348889174, 'clip_high': 1.1485615677414902}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,267] Trial 73 finished with value: 21080.545011719765 and parameters: {'n_lags': 8, 'alpha': 0.6857497458021609, 't2': 4, 'clip_low': 0.8368598511837068, 'clip_high': 1.7220360091861027}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,286] Trial 74 finished with value: 21048.527233210978 and parameters: {'n_lags': 9, 'alpha': 0.7039809138365806, 't2': 4, 'clip_low': 0.8547279242328917, 'clip_high': 1.2186712967192979}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,305] Trial 75 finished with value: 21078.204949447736 and parameters: {'n_lags': 8, 'alpha': 0.6100121256487697, 't2': 3, 'clip_low': 0.8230305995465083, 'clip_high': 1.1654600555675387}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,324] Trial 76 finished with value: 21046.595583132446 and parameters: {'n_lags': 9, 'alpha': 0.6878820188191868, 't2': 4, 'clip_low': 0.8458314745978154, 'clip_high': 1.126381229052021}. Best is trial 65 with value: 21046.1980839348.
# [I 2025-09-30 02:04:47,342] Trial 77 finished with value: 21046.174554482433 and parameters: {'n_lags': 9, 'alpha': 0.6798051813158659, 't2': 4, 'clip_low': 0.8463927843970026, 'clip_high': 1.1361392822328171}. Best is trial 77 with value: 21046.174554482433.
# [I 2025-09-30 02:04:47,362] Trial 78 finished with value: 21046.40689056615 and parameters: {'n_lags': 9, 'alpha': 0.6850456232459151, 't2': 4, 'clip_low': 0.8663584922349419, 'clip_high': 1.1326097704463558}. Best is trial 77 with value: 21046.174554482433.
# [I 2025-09-30 02:04:47,381] Trial 79 finished with value: 21056.808190651813 and parameters: {'n_lags': 9, 'alpha': 0.7355196112939539, 't2': 4, 'clip_low': 0.8754854066811925, 'clip_high': 1.134120791898575}. Best is trial 77 with value: 21046.174554482433.
# [I 2025-09-30 02:04:47,400] Trial 80 finished with value: 21079.289257441797 and parameters: {'n_lags': 8, 'alpha': 0.6796074112741334, 't2': 3, 'clip_low': 0.866980129696852, 'clip_high': 1.5333031408039557}. Best is trial 77 with value: 21046.174554482433.
# [I 2025-09-30 02:04:47,418] Trial 81 finished with value: 21047.045768678203 and parameters: {'n_lags': 9, 'alpha': 0.6929631070313778, 't2': 4, 'clip_low': 0.8432875720122394, 'clip_high': 1.1200657532906049}. Best is trial 77 with value: 21046.174554482433.
# [I 2025-09-30 02:04:47,436] Trial 82 finished with value: 21062.026633834244 and parameters: {'n_lags': 9, 'alpha': 0.7484021452383639, 't2': 4, 'clip_low': 0.8478780572122004, 'clip_high': 1.1321053367108094}. Best is trial 77 with value: 21046.174554482433.
# [I 2025-09-30 02:04:47,455] Trial 83 finished with value: 21046.106442139953 and parameters: {'n_lags': 9, 'alpha': 0.6766418375881843, 't2': 4, 'clip_low': 0.8576205317221778, 'clip_high': 1.1215078056825118}. Best is trial 83 with value: 21046.106442139953.
# [I 2025-09-30 02:04:47,475] Trial 84 finished with value: 21046.188838435828 and parameters: {'n_lags': 9, 'alpha': 0.6802615084411964, 't2': 4, 'clip_low': 0.8922956406971855, 'clip_high': 1.1991332917414539}. Best is trial 83 with value: 21046.106442139953.
# [I 2025-09-30 02:04:47,493] Trial 85 finished with value: 21079.042951378484 and parameters: {'n_lags': 8, 'alpha': 0.6782798575103721, 't2': 4, 'clip_low': 0.890714151167952, 'clip_high': 1.2040288489808337}. Best is trial 83 with value: 21046.106442139953.
# [I 2025-09-30 02:04:47,512] Trial 86 finished with value: 21091.312613360646 and parameters: {'n_lags': 8, 'alpha': 0.7205594860163101, 't2': 3, 'clip_low': 0.92276122780285, 'clip_high': 1.2495663787110158}. Best is trial 83 with value: 21046.106442139953.
# [I 2025-09-30 02:04:47,530] Trial 87 finished with value: 21085.929226510954 and parameters: {'n_lags': 9, 'alpha': 0.7887394200991233, 't2': 4, 'clip_low': 0.8603838327993321, 'clip_high': 1.2323342018777885}. Best is trial 83 with value: 21046.106442139953.
# [I 2025-09-30 02:04:47,549] Trial 88 finished with value: 21069.14582966743 and parameters: {'n_lags': 9, 'alpha': 0.7626928757792482, 't2': 3, 'clip_low': 0.8897131851098204, 'clip_high': 1.171927875204111}. Best is trial 83 with value: 21046.106442139953.
# [I 2025-09-30 02:04:47,568] Trial 89 finished with value: 21076.184764663452 and parameters: {'n_lags': 8, 'alpha': 0.6281560488553304, 't2': 4, 'clip_low': 0.828792003765509, 'clip_high': 1.6312444018101058}. Best is trial 83 with value: 21046.106442139953.
# [I 2025-09-30 02:04:47,586] Trial 90 finished with value: 21049.72482444692 and parameters: {'n_lags': 9, 'alpha': 0.7104356647810957, 't2': 4, 'clip_low': 0.8722484427874689, 'clip_high': 1.1934409312091236}. Best is trial 83 with value: 21046.106442139953.
# [I 2025-09-30 02:04:47,605] Trial 91 finished with value: 21046.480663522085 and parameters: {'n_lags': 9, 'alpha': 0.6862360669558661, 't2': 4, 'clip_low': 0.8439161357519905, 'clip_high': 1.1156308415066594}. Best is trial 83 with value: 21046.106442139953.
# [I 2025-09-30 02:04:47,624] Trial 92 finished with value: 21046.09174476183 and parameters: {'n_lags': 9, 'alpha': 0.6748668555369326, 't2': 4, 'clip_low': 0.8533818493991171, 'clip_high': 1.1415339478226119}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,642] Trial 93 finished with value: 21053.73199407142 and parameters: {'n_lags': 9, 'alpha': 0.6191044904634644, 't2': 4, 'clip_low': 0.8530279848678467, 'clip_high': 1.1443065481716723}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,661] Trial 94 finished with value: 21046.09858654664 and parameters: {'n_lags': 9, 'alpha': 0.6759365894288644, 't2': 4, 'clip_low': 0.8616483517515473, 'clip_high': 1.1120421010548185}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,680] Trial 95 finished with value: 21046.14762809727 and parameters: {'n_lags': 9, 'alpha': 0.6695564831189529, 't2': 4, 'clip_low': 0.8619619740269993, 'clip_high': 1.1168197716343502}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,699] Trial 96 finished with value: 21077.35696940463 and parameters: {'n_lags': 8, 'alpha': 0.6673840491813033, 't2': 4, 'clip_low': 0.862802841970974, 'clip_high': 1.1145473693441805}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,718] Trial 97 finished with value: 21050.060125394084 and parameters: {'n_lags': 10, 'alpha': 0.636641406702056, 't2': 4, 'clip_low': 0.8518892818055929, 'clip_high': 1.1406321353622018}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,737] Trial 98 finished with value: 21069.36878606824 and parameters: {'n_lags': 9, 'alpha': 0.5763872759860179, 't2': 3, 'clip_low': 0.8885883653079792, 'clip_high': 1.1036835877326736}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,756] Trial 99 finished with value: 21078.038342759188 and parameters: {'n_lags': 8, 'alpha': 0.6722646374393488, 't2': 4, 'clip_low': 0.8970732390317886, 'clip_high': 1.1767256631106349}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,775] Trial 100 finished with value: 21057.038119799094 and parameters: {'n_lags': 10, 'alpha': 0.7106217170145068, 't2': 3, 'clip_low': 0.8772779843936976, 'clip_high': 1.1118623058426813}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,794] Trial 101 finished with value: 21046.174933772843 and parameters: {'n_lags': 9, 'alpha': 0.668550460727541, 't2': 4, 'clip_low': 0.8580433485336002, 'clip_high': 1.1246186051628253}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,813] Trial 102 finished with value: 21057.8476022497 and parameters: {'n_lags': 9, 'alpha': 0.7383178420457346, 't2': 4, 'clip_low': 0.8631771751469665, 'clip_high': 1.4311202905686884}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,832] Trial 103 finished with value: 21056.583030740996 and parameters: {'n_lags': 9, 'alpha': 0.6093651101554864, 't2': 4, 'clip_low': 0.8684178266029319, 'clip_high': 1.1385967336597729}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,857] Trial 104 finished with value: 21046.136490209214 and parameters: {'n_lags': 9, 'alpha': 0.6700354251328943, 't2': 4, 'clip_low': 0.8577331661284286, 'clip_high': 1.1198541303886487}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,912] Trial 105 finished with value: 21049.722068180025 and parameters: {'n_lags': 10, 'alpha': 0.6391107120171655, 't2': 4, 'clip_low': 0.8586005771796942, 'clip_high': 1.1176982602325407}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,938] Trial 106 finished with value: 21046.179863697038 and parameters: {'n_lags': 9, 'alpha': 0.668387205196859, 't2': 4, 'clip_low': 0.8395998304079337, 'clip_high': 1.1005216307579777}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,958] Trial 107 finished with value: 21091.146607284085 and parameters: {'n_lags': 8, 'alpha': 0.7201428612318062, 't2': 4, 'clip_low': 0.8844842943049609, 'clip_high': 1.1033855902174976}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,977] Trial 108 finished with value: 21048.34509637608 and parameters: {'n_lags': 10, 'alpha': 0.6637936590912599, 't2': 4, 'clip_low': 0.8714551629041574, 'clip_high': 1.1308447254209684}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:47,996] Trial 109 finished with value: 21495.45353526143 and parameters: {'n_lags': 4, 'alpha': 0.6251543653666735, 't2': 4, 'clip_low': 0.8513186214793871, 'clip_high': 1.1473237261453462}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:48,016] Trial 110 finished with value: 21046.40968949971 and parameters: {'n_lags': 9, 'alpha': 0.6631801527420726, 't2': 4, 'clip_low': 0.8394494957733558, 'clip_high': 1.187577586536233}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:48,035] Trial 111 finished with value: 21046.146934152475 and parameters: {'n_lags': 9, 'alpha': 0.6695848817968122, 't2': 4, 'clip_low': 0.8395915994743056, 'clip_high': 1.184646201714389}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:48,054] Trial 112 finished with value: 21301.518431645323 and parameters: {'n_lags': 9, 'alpha': 0.94310165105007, 't2': 4, 'clip_low': 0.8575997631573271, 'clip_high': 1.1238641157965938}. Best is trial 92 with value: 21046.09174476183.
# [I 2025-09-30 02:04:48,073] Trial 113 finished with value: 21046.09150788327 and parameters: {'n_lags': 9, 'alpha': 0.6747962447258404, 't2': 4, 'clip_low': 0.820643845688481, 'clip_high': 1.1720102982909282}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,091] Trial 114 finished with value: 21048.298828249946 and parameters: {'n_lags': 9, 'alpha': 0.6449399352197006, 't2': 4, 'clip_low': 0.8210090706894196, 'clip_high': 1.1716586166435885}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,111] Trial 115 finished with value: 21046.162651936105 and parameters: {'n_lags': 9, 'alpha': 0.6689791186773624, 't2': 3, 'clip_low': 0.8199168034006264, 'clip_high': 1.2050934818091166}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,130] Trial 116 finished with value: 21082.997666892643 and parameters: {'n_lags': 8, 'alpha': 0.5873119829251072, 't2': 3, 'clip_low': 0.8190827736504245, 'clip_high': 1.2042112812063348}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,149] Trial 117 finished with value: 21059.153119689367 and parameters: {'n_lags': 10, 'alpha': 0.5995122441930899, 't2': 3, 'clip_low': 0.8066365481802495, 'clip_high': 1.1839058790929353}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,168] Trial 118 finished with value: 21046.21993477749 and parameters: {'n_lags': 9, 'alpha': 0.6671988792343274, 't2': 3, 'clip_low': 0.8491440294663372, 'clip_high': 1.1470209996160288}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,187] Trial 119 finished with value: 21049.861025249567 and parameters: {'n_lags': 9, 'alpha': 0.6357958525798019, 't2': 4, 'clip_low': 0.8099059733169668, 'clip_high': 1.103350434980191}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,206] Trial 120 finished with value: 21103.95119457637 and parameters: {'n_lags': 7, 'alpha': 0.7085158552011263, 't2': 4, 'clip_low': 0.8266406232605691, 'clip_high': 1.3185151986242007}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,226] Trial 121 finished with value: 21046.099517331593 and parameters: {'n_lags': 9, 'alpha': 0.672364319289559, 't2': 4, 'clip_low': 0.8401569585260562, 'clip_high': 1.1630849596459627}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,245] Trial 122 finished with value: 21047.310064502264 and parameters: {'n_lags': 9, 'alpha': 0.652538633014204, 't2': 4, 'clip_low': 0.8556957205812441, 'clip_high': 1.1640183537308584}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,264] Trial 123 finished with value: 21046.149546270313 and parameters: {'n_lags': 9, 'alpha': 0.6694788665796422, 't2': 4, 'clip_low': 0.9149065509011417, 'clip_high': 1.2888750752408475}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,283] Trial 124 finished with value: 21055.08892698763 and parameters: {'n_lags': 9, 'alpha': 0.6142854397366966, 't2': 4, 'clip_low': 0.8168725216882872, 'clip_high': 1.1385012520417161}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,302] Trial 125 finished with value: 21063.299920730966 and parameters: {'n_lags': 10, 'alpha': 0.7253198465580272, 't2': 4, 'clip_low': 0.9395661996719982, 'clip_high': 1.36975150515848}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,321] Trial 126 finished with value: 21048.619191022957 and parameters: {'n_lags': 9, 'alpha': 0.7045281592185797, 't2': 3, 'clip_low': 0.9244294734825861, 'clip_high': 1.1755921103913312}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,341] Trial 127 finished with value: 21077.598790720895 and parameters: {'n_lags': 8, 'alpha': 0.6692165835162787, 't2': 4, 'clip_low': 0.8406251791111251, 'clip_high': 1.2963953308601863}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,360] Trial 128 finished with value: 21686.96399574319 and parameters: {'n_lags': 9, 'alpha': 0.2091713763738069, 't2': 4, 'clip_low': 0.8321154547828934, 'clip_high': 1.1207052793367975}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,379] Trial 129 finished with value: 21049.127809607216 and parameters: {'n_lags': 10, 'alpha': 0.6442903460862838, 't2': 4, 'clip_low': 0.8399699099877187, 'clip_high': 1.1005664027456707}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,405] Trial 130 finished with value: 21047.170222871024 and parameters: {'n_lags': 9, 'alpha': 0.6538318334986486, 't2': 5, 'clip_low': 0.8478195043966676, 'clip_high': 1.159502953378971}. Best is trial 113 with value: 21046.09150788327.
# [I 2025-09-30 02:04:48,425] Trial 131 finished with value: 21046.091174844205 and parameters: {'n_lags': 9, 'alpha': 0.6746796390548817, 't2': 4, 'clip_low': 0.9163438392547377, 'clip_high': 1.2114918437757993}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,444] Trial 132 finished with value: 21047.787488947015 and parameters: {'n_lags': 9, 'alpha': 0.6991215245797254, 't2': 4, 'clip_low': 0.919595702211181, 'clip_high': 1.2178201737892969}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,463] Trial 133 finished with value: 21046.14820744348 and parameters: {'n_lags': 9, 'alpha': 0.669532905568478, 't2': 4, 'clip_low': 0.8638050120628874, 'clip_high': 1.2814765032623652}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,483] Trial 134 finished with value: 21050.83863190306 and parameters: {'n_lags': 9, 'alpha': 0.6310059362088298, 't2': 4, 'clip_low': 0.9130671142358694, 'clip_high': 1.24773281001364}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,502] Trial 135 finished with value: 21084.052481057795 and parameters: {'n_lags': 8, 'alpha': 0.6994999251366665, 't2': 4, 'clip_low': 0.9277247320496087, 'clip_high': 1.333446566426646}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,521] Trial 136 finished with value: 21051.62296500996 and parameters: {'n_lags': 9, 'alpha': 0.7186942054212222, 't2': 4, 'clip_low': 0.8640797896808774, 'clip_high': 1.2607482508708423}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,541] Trial 137 finished with value: 21080.012293056545 and parameters: {'n_lags': 10, 'alpha': 0.7524468383129348, 't2': 3, 'clip_low': 0.8991563480344833, 'clip_high': 1.3956856054340958}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,560] Trial 138 finished with value: 21046.12099877939 and parameters: {'n_lags': 9, 'alpha': 0.6775785982032824, 't2': 4, 'clip_low': 0.9111540776293433, 'clip_high': 1.1912157288702188}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,578] Trial 139 finished with value: 21098.724130752915 and parameters: {'n_lags': 8, 'alpha': 0.737269609601507, 't2': 5, 'clip_low': 0.871076303385437, 'clip_high': 1.2394392858566181}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,598] Trial 140 finished with value: 21046.984171552092 and parameters: {'n_lags': 9, 'alpha': 0.6556873322042533, 't2': 4, 'clip_low': 0.9087580875032091, 'clip_high': 1.2761313662690985}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,617] Trial 141 finished with value: 21046.1035772141 and parameters: {'n_lags': 9, 'alpha': 0.6764109524052497, 't2': 4, 'clip_low': 0.8597990779389779, 'clip_high': 1.1945254615454106}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,637] Trial 142 finished with value: 21046.152253591627 and parameters: {'n_lags': 9, 'alpha': 0.6790059903829564, 't2': 4, 'clip_low': 0.9332007814922608, 'clip_high': 1.2278245863158455}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,656] Trial 143 finished with value: 21047.563665044192 and parameters: {'n_lags': 9, 'alpha': 0.6974420036262906, 't2': 4, 'clip_low': 0.9356049749340396, 'clip_high': 1.2851045062089026}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,675] Trial 144 finished with value: 21049.206958692786 and parameters: {'n_lags': 9, 'alpha': 0.6393449685868288, 't2': 4, 'clip_low': 0.9165363520312484, 'clip_high': 1.2084099809675959}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,695] Trial 145 finished with value: 21046.113634777957 and parameters: {'n_lags': 9, 'alpha': 0.677142410043686, 't2': 4, 'clip_low': 0.9378917068489189, 'clip_high': 1.2302748277860405}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,714] Trial 146 finished with value: 21046.24127280358 and parameters: {'n_lags': 9, 'alpha': 0.6817002138500271, 't2': 4, 'clip_low': 0.9353889994020961, 'clip_high': 1.2609204372538616}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,733] Trial 147 finished with value: 21158.664671974027 and parameters: {'n_lags': 9, 'alpha': 0.4546822332530364, 't2': 4, 'clip_low': 0.9296388062730457, 'clip_high': 1.2232265363748958}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,752] Trial 148 finished with value: 21053.273891163863 and parameters: {'n_lags': 10, 'alpha': 0.6198100150106478, 't2': 4, 'clip_low': 0.9489978942048569, 'clip_high': 1.1881539395751248}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,771] Trial 149 finished with value: 21076.099563055253 and parameters: {'n_lags': 8, 'alpha': 0.653997052755815, 't2': 4, 'clip_low': 0.9415069539584975, 'clip_high': 1.2367853791807653}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,791] Trial 150 finished with value: 21049.039841729085 and parameters: {'n_lags': 9, 'alpha': 0.7069090763973448, 't2': 4, 'clip_low': 0.9295443552152921, 'clip_high': 1.1980631531619939}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,811] Trial 151 finished with value: 21046.193238999844 and parameters: {'n_lags': 9, 'alpha': 0.6679655820204433, 't2': 4, 'clip_low': 0.9134935244643199, 'clip_high': 1.225612591037015}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,829] Trial 152 finished with value: 21046.76916905595 and parameters: {'n_lags': 9, 'alpha': 0.6900408630649677, 't2': 4, 'clip_low': 0.9201053610149661, 'clip_high': 1.2143453046051496}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,849] Trial 153 finished with value: 21046.121868810045 and parameters: {'n_lags': 9, 'alpha': 0.6776264469581837, 't2': 4, 'clip_low': 0.9040752788940678, 'clip_high': 1.1867485445525245}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,868] Trial 154 finished with value: 21046.09948432034 and parameters: {'n_lags': 9, 'alpha': 0.6760310462416402, 't2': 4, 'clip_low': 0.8809210109661344, 'clip_high': 1.1747820378549145}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,887] Trial 155 finished with value: 21052.182358278853 and parameters: {'n_lags': 9, 'alpha': 0.7208312784143592, 't2': 4, 'clip_low': 0.8601028209915016, 'clip_high': 1.1763936773875512}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,906] Trial 156 finished with value: 21048.066759054756 and parameters: {'n_lags': 9, 'alpha': 0.6465420799899805, 't2': 4, 'clip_low': 0.8810586334781078, 'clip_high': 1.1894717218147175}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,926] Trial 157 finished with value: 21047.086489468045 and parameters: {'n_lags': 9, 'alpha': 0.6933546459386866, 't2': 4, 'clip_low': 0.9078805650574149, 'clip_high': 1.1538154690662181}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,945] Trial 158 finished with value: 21050.71497319768 and parameters: {'n_lags': 9, 'alpha': 0.6315836785609922, 't2': 4, 'clip_low': 0.8985176984692695, 'clip_high': 1.1706041645082441}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,963] Trial 159 finished with value: 21048.31044375867 and parameters: {'n_lags': 10, 'alpha': 0.6604854406131606, 't2': 4, 'clip_low': 0.9026164860198713, 'clip_high': 1.193974967261172}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:48,983] Trial 160 finished with value: 21079.95495016558 and parameters: {'n_lags': 8, 'alpha': 0.6829793543319282, 't2': 4, 'clip_low': 0.8845661957938696, 'clip_high': 1.167549723762657}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:49,003] Trial 161 finished with value: 21046.096004239127 and parameters: {'n_lags': 9, 'alpha': 0.6756304059305571, 't2': 4, 'clip_low': 0.8750825956080828, 'clip_high': 1.2366544132073811}. Best is trial 131 with value: 21046.091174844205.
# [I 2025-09-30 02:04:49,021] Trial 162 finished with value: 21046.090856607665 and parameters: {'n_lags': 9, 'alpha': 0.6745317591366755, 't2': 4, 'clip_low': 0.8671708453268184, 'clip_high': 1.2069976952367016}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,041] Trial 163 finished with value: 21050.67991438809 and parameters: {'n_lags': 9, 'alpha': 0.714816474583342, 't2': 4, 'clip_low': 0.871715288314714, 'clip_high': 1.2068882515022514}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,060] Trial 164 finished with value: 21047.29220469212 and parameters: {'n_lags': 9, 'alpha': 0.6952179955267929, 't2': 4, 'clip_low': 0.8758114076320689, 'clip_high': 1.1501771158282914}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,079] Trial 165 finished with value: 21047.049489233472 and parameters: {'n_lags': 9, 'alpha': 0.6550160632271022, 't2': 4, 'clip_low': 0.8657427048731341, 'clip_high': 1.2408694047439275}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,099] Trial 166 finished with value: 21046.109028860803 and parameters: {'n_lags': 9, 'alpha': 0.6768328957937723, 't2': 4, 'clip_low': 0.8567911603147175, 'clip_high': 1.1836321707674884}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,118] Trial 167 finished with value: 21055.016663833 and parameters: {'n_lags': 9, 'alpha': 0.730332229570014, 't2': 4, 'clip_low': 0.855398832584118, 'clip_high': 1.188936428990576}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,137] Trial 168 finished with value: 21049.77368442691 and parameters: {'n_lags': 10, 'alpha': 0.6815537732395818, 't2': 7, 'clip_low': 0.8687462589418072, 'clip_high': 1.1726557279902978}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,156] Trial 169 finished with value: 21049.12080483195 and parameters: {'n_lags': 9, 'alpha': 0.6398383567138455, 't2': 4, 'clip_low': 0.8615420782472255, 'clip_high': 1.181909306261498}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,176] Trial 170 finished with value: 21048.216429014883 and parameters: {'n_lags': 9, 'alpha': 0.7020475781324675, 't2': 4, 'clip_low': 0.8511769785841303, 'clip_high': 1.141984798436151}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,203] Trial 171 finished with value: 21046.105352524115 and parameters: {'n_lags': 9, 'alpha': 0.6718396817044731, 't2': 4, 'clip_low': 0.87580295083553, 'clip_high': 1.2121717772905272}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,222] Trial 172 finished with value: 21046.13623208305 and parameters: {'n_lags': 9, 'alpha': 0.6783367200037838, 't2': 4, 'clip_low': 0.8771602874005859, 'clip_high': 1.2173708275022634}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,242] Trial 173 finished with value: 21046.535546665127 and parameters: {'n_lags': 9, 'alpha': 0.6870490368724176, 't2': 4, 'clip_low': 0.8756872153306376, 'clip_high': 1.212877845467866}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,262] Trial 174 finished with value: 21047.976314841897 and parameters: {'n_lags': 9, 'alpha': 0.6471911328063275, 't2': 4, 'clip_low': 0.8815855885105265, 'clip_high': 1.1978817519258957}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,281] Trial 175 finished with value: 21046.10083906216 and parameters: {'n_lags': 9, 'alpha': 0.6761649758694424, 't2': 4, 'clip_low': 0.8949876314045622, 'clip_high': 1.2298705233011327}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,301] Trial 176 finished with value: 21046.99497235521 and parameters: {'n_lags': 9, 'alpha': 0.6555747106011408, 't2': 4, 'clip_low': 0.8945860561982066, 'clip_high': 1.22871175004668}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,320] Trial 177 finished with value: 21085.715575486447 and parameters: {'n_lags': 8, 'alpha': 0.7049643431267375, 't2': 4, 'clip_low': 0.8857487184716579, 'clip_high': 1.2155747515133242}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,339] Trial 178 finished with value: 21046.16603450591 and parameters: {'n_lags': 9, 'alpha': 0.6795141833435239, 't2': 4, 'clip_low': 0.904434649946127, 'clip_high': 1.249158579170391}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,359] Trial 179 finished with value: 21050.09363615434 and parameters: {'n_lags': 9, 'alpha': 0.7121913022838593, 't2': 4, 'clip_low': 0.8749989387073823, 'clip_high': 1.2053753746420242}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,378] Trial 180 finished with value: 21051.907794543426 and parameters: {'n_lags': 10, 'alpha': 0.6931794379324304, 't2': 4, 'clip_low': 0.8868163263246988, 'clip_high': 1.2321506494072516}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,397] Trial 181 finished with value: 21046.21403595739 and parameters: {'n_lags': 9, 'alpha': 0.6673609691920578, 't2': 4, 'clip_low': 0.8684067327587378, 'clip_high': 1.1944867715480425}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,417] Trial 182 finished with value: 21046.117365669186 and parameters: {'n_lags': 9, 'alpha': 0.677370949160927, 't2': 4, 'clip_low': 0.8782964948331775, 'clip_high': 1.1633425654974645}. Best is trial 162 with value: 21046.090856607665.
# [I 2025-09-30 02:04:49,436] Trial 183 finished with value: 21046.189568110796 and parameters: {'n_lags': 9, 'alpha': 0.6802838915882576, 't2': 4, 'clip_low': 0.8792498282168179, 'clip_high': 1.1593934813062048}. Best is trial 162 with value: 21046.090856607665.
# ...
# [I 2025-09-30 02:04:55,055] Trial 452 finished with value: 21046.355876912752 and parameters: {'n_lags': 9, 'alpha': 0.6841377276097842, 't2': 4, 'clip_low': 0.922325005398119, 'clip_high': 1.172684194090054}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,076] Trial 453 finished with value: 21116.589670818008 and parameters: {'n_lags': 9, 'alpha': 0.8235374187792938, 't2': 5, 'clip_low': 0.8942495744787821, 'clip_high': 1.3361797845176218}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,118] Trial 454 finished with value: 21046.091549180386 and parameters: {'n_lags': 9, 'alpha': 0.6735928230113742, 't2': 4, 'clip_low': 0.8165545320522258, 'clip_high': 1.1580229578730277}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,180] Trial 455 finished with value: 21053.893155988688 and parameters: {'n_lags': 9, 'alpha': 0.6185118482388197, 't2': 4, 'clip_low': 0.8154736486362021, 'clip_high': 1.1559791969091082}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,201] Trial 456 finished with value: 21046.44389814029 and parameters: {'n_lags': 9, 'alpha': 0.6626009790180137, 't2': 4, 'clip_low': 0.8086395210296433, 'clip_high': 1.1622359398912738}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,223] Trial 457 finished with value: 21046.090865901464 and parameters: {'n_lags': 9, 'alpha': 0.6738652426344675, 't2': 4, 'clip_low': 0.8214345239227093, 'clip_high': 1.173646908076069}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,252] Trial 458 finished with value: 21050.126558862456 and parameters: {'n_lags': 9, 'alpha': 0.6344408906369162, 't2': 4, 'clip_low': 0.8138768653801116, 'clip_high': 1.1497442212845785}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,273] Trial 459 finished with value: 21047.395380178714 and parameters: {'n_lags': 9, 'alpha': 0.6960909332523697, 't2': 4, 'clip_low': 0.7992059890856018, 'clip_high': 1.1698465931928137}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,294] Trial 460 finished with value: 21048.44115712061 and parameters: {'n_lags': 10, 'alpha': 0.6540711593953024, 't2': 4, 'clip_low': 0.8119275114637432, 'clip_high': 1.1484982899954765}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,315] Trial 461 finished with value: 21046.17718157561 and parameters: {'n_lags': 9, 'alpha': 0.6798918819082614, 't2': 4, 'clip_low': 0.8060289768617657, 'clip_high': 1.1648248904653462}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,336] Trial 462 finished with value: 21048.78844725881 and parameters: {'n_lags': 9, 'alpha': 0.70550913468176, 't2': 4, 'clip_low': 0.8111815607892925, 'clip_high': 1.1393889038339948}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,356] Trial 463 finished with value: 21046.213508310775 and parameters: {'n_lags': 9, 'alpha': 0.6673756535582103, 't2': 4, 'clip_low': 0.8149312112294153, 'clip_high': 1.1738543345669576}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,378] Trial 464 finished with value: 21081.42115440023 and parameters: {'n_lags': 8, 'alpha': 0.6895636956117583, 't2': 4, 'clip_low': 0.8189128203875659, 'clip_high': 1.1610416813864524}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,398] Trial 465 finished with value: 21048.227566242964 and parameters: {'n_lags': 9, 'alpha': 0.6454228064211947, 't2': 5, 'clip_low': 0.8226395104095025, 'clip_high': 1.1481784314500563}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,419] Trial 466 finished with value: 21046.094025380728 and parameters: {'n_lags': 9, 'alpha': 0.67534126852743, 't2': 4, 'clip_low': 0.8242407640167578, 'clip_high': 1.1347094802438256}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,440] Trial 467 finished with value: 21046.26613830568 and parameters: {'n_lags': 9, 'alpha': 0.682292623193342, 't2': 4, 'clip_low': 0.8192461425006909, 'clip_high': 1.1351169501520644}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,461] Trial 468 finished with value: 21046.78936805204 and parameters: {'n_lags': 9, 'alpha': 0.6578473278630065, 't2': 4, 'clip_low': 0.8161906470181074, 'clip_high': 1.1339771896212012}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,482] Trial 469 finished with value: 21049.33428625297 and parameters: {'n_lags': 9, 'alpha': 0.7084721819882058, 't2': 4, 'clip_low': 0.8117493653514319, 'clip_high': 1.1292684013035024}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,503] Trial 470 finished with value: 21046.09384139188 and parameters: {'n_lags': 9, 'alpha': 0.6730904872252782, 't2': 4, 'clip_low': 0.826810753139993, 'clip_high': 1.150567654951376}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,524] Trial 471 finished with value: 21077.32173381785 and parameters: {'n_lags': 8, 'alpha': 0.6671058805853171, 't2': 4, 'clip_low': 0.8267047492321214, 'clip_high': 1.1443644968632023}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,552] Trial 472 finished with value: 21049.29869668823 and parameters: {'n_lags': 10, 'alpha': 0.6426530123077111, 't2': 4, 'clip_low': 0.8216110104221684, 'clip_high': 1.1247203539438582}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,572] Trial 473 finished with value: 21055.52867350342 and parameters: {'n_lags': 9, 'alpha': 0.7318674121910012, 't2': 3, 'clip_low': 0.774044930655985, 'clip_high': 1.1488488811445154}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,594] Trial 474 finished with value: 21046.708340357145 and parameters: {'n_lags': 9, 'alpha': 0.6893203408594802, 't2': 5, 'clip_low': 0.8244527505992671, 'clip_high': 1.1297239459388435}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,614] Trial 475 finished with value: 21046.115933931756 and parameters: {'n_lags': 9, 'alpha': 0.6711068451134217, 't2': 4, 'clip_low': 0.8205508042420889, 'clip_high': 1.1551952418807971}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,636] Trial 476 finished with value: 21047.139803575967 and parameters: {'n_lags': 9, 'alpha': 0.6541238154572732, 't2': 4, 'clip_low': 0.8261574883284178, 'clip_high': 1.1407593199059582}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,657] Trial 477 finished with value: 21047.489233483255 and parameters: {'n_lags': 9, 'alpha': 0.6968547548324608, 't2': 4, 'clip_low': 0.8036718048338459, 'clip_high': 1.1223181965427063}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,677] Trial 478 finished with value: 21051.19647411612 and parameters: {'n_lags': 9, 'alpha': 0.7169873236468619, 't2': 4, 'clip_low': 0.8305649990672472, 'clip_high': 1.1964126202794956}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,698] Trial 479 finished with value: 21046.163022130404 and parameters: {'n_lags': 9, 'alpha': 0.6794073703462492, 't2': 4, 'clip_low': 0.8184808851501713, 'clip_high': 1.1571001502510112}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,719] Trial 480 finished with value: 21046.460976360268 and parameters: {'n_lags': 9, 'alpha': 0.6623222149799087, 't2': 4, 'clip_low': 0.8096705733700765, 'clip_high': 1.1380737228210192}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,740] Trial 481 finished with value: 21050.700280160905 and parameters: {'n_lags': 10, 'alpha': 0.6325288697800527, 't2': 4, 'clip_low': 0.85952589884754, 'clip_high': 1.1783113886335081}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,762] Trial 482 finished with value: 21046.595114421303 and parameters: {'n_lags': 9, 'alpha': 0.6878757164811873, 't2': 4, 'clip_low': 0.8276850700117769, 'clip_high': 1.2018347736128279}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,783] Trial 483 finished with value: 21046.097474157654 and parameters: {'n_lags': 9, 'alpha': 0.6725877082502556, 't2': 4, 'clip_low': 0.823815086243901, 'clip_high': 1.124566285143727}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,804] Trial 484 finished with value: 21047.96633300309 and parameters: {'n_lags': 9, 'alpha': 0.6472636853069517, 't2': 6, 'clip_low': 0.8244701385851849, 'clip_high': 1.1501902851090513}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,825] Trial 485 finished with value: 21077.93427866841 and parameters: {'n_lags': 8, 'alpha': 0.6715714436781547, 't2': 4, 'clip_low': 0.8188738310209581, 'clip_high': 1.167193908727455}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,853] Trial 486 finished with value: 21048.17769751995 and parameters: {'n_lags': 9, 'alpha': 0.7017966826785809, 't2': 4, 'clip_low': 0.7821493425572233, 'clip_high': 1.1418959436409026}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,875] Trial 487 finished with value: 21373.275542721305 and parameters: {'n_lags': 5, 'alpha': 0.6603738463128201, 't2': 4, 'clip_low': 0.820825915956673, 'clip_high': 1.1842438724513786}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,896] Trial 488 finished with value: 21091.28254833022 and parameters: {'n_lags': 9, 'alpha': 0.5362960466402635, 't2': 4, 'clip_low': 0.828807201254171, 'clip_high': 1.1314596790274527}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,917] Trial 489 finished with value: 21046.235449192653 and parameters: {'n_lags': 9, 'alpha': 0.6815544840029356, 't2': 5, 'clip_low': 0.8148577726558843, 'clip_high': 1.2157712395665978}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,938] Trial 490 finished with value: 21049.691118271785 and parameters: {'n_lags': 9, 'alpha': 0.636687131451194, 't2': 4, 'clip_low': 0.8169212289237394, 'clip_high': 1.1571017496224727}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,959] Trial 491 finished with value: 21046.87368624855 and parameters: {'n_lags': 9, 'alpha': 0.6568801837256083, 't2': 4, 'clip_low': 0.7877434417431736, 'clip_high': 1.1188737949545853}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:55,980] Trial 492 finished with value: 21053.46356986836 and parameters: {'n_lags': 10, 'alpha': 0.6190161974614237, 't2': 4, 'clip_low': 0.8234693445307927, 'clip_high': 1.1717213202598205}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,002] Trial 493 finished with value: 21047.151275790147 and parameters: {'n_lags': 9, 'alpha': 0.6939610896300825, 't2': 3, 'clip_low': 0.8306929833529905, 'clip_high': 1.2235097595707474}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,022] Trial 494 finished with value: 21046.12125543268 and parameters: {'n_lags': 9, 'alpha': 0.6775927838559387, 't2': 4, 'clip_low': 0.806865841315029, 'clip_high': 1.1981782074068175}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,043] Trial 495 finished with value: 21049.014800557645 and parameters: {'n_lags': 9, 'alpha': 0.7067724768702686, 't2': 4, 'clip_low': 0.8216275712517422, 'clip_high': 1.1406358757707817}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,064] Trial 496 finished with value: 21046.09573829341 and parameters: {'n_lags': 9, 'alpha': 0.6728052265959091, 't2': 4, 'clip_low': 0.7488362116763067, 'clip_high': 1.1595926537746748}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,085] Trial 497 finished with value: 21076.014238693188 and parameters: {'n_lags': 8, 'alpha': 0.6524964253645383, 't2': 4, 'clip_low': 0.7760768054641592, 'clip_high': 1.1829081158230825}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,106] Trial 498 finished with value: 21046.65401965425 and parameters: {'n_lags': 9, 'alpha': 0.688645752223736, 't2': 4, 'clip_low': 0.7461857442954373, 'clip_high': 1.1611100499794933}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,128] Trial 499 finished with value: 21051.117344216113 and parameters: {'n_lags': 9, 'alpha': 0.7166625024868013, 't2': 4, 'clip_low': 0.7608430551150227, 'clip_high': 1.1689948591651866}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,156] Trial 500 finished with value: 21049.287215757962 and parameters: {'n_lags': 11, 'alpha': 0.6662073068891284, 't2': 4, 'clip_low': 0.7107311380745359, 'clip_high': 1.2040443425454856}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,178] Trial 501 finished with value: 21064.957968925002 and parameters: {'n_lags': 9, 'alpha': 0.754639024315884, 't2': 4, 'clip_low': 0.7023112032581266, 'clip_high': 1.458948189942633}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,198] Trial 502 finished with value: 21049.36135220507 and parameters: {'n_lags': 9, 'alpha': 0.6384770129425269, 't2': 4, 'clip_low': 0.8678760244752458, 'clip_high': 1.5918510070499}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,219] Trial 503 finished with value: 21047.22464051939 and parameters: {'n_lags': 9, 'alpha': 0.6946253985363987, 't2': 4, 'clip_low': 0.7402008938529725, 'clip_high': 1.1865710027900536}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,240] Trial 504 finished with value: 21046.092419206918 and parameters: {'n_lags': 9, 'alpha': 0.6733658483436825, 't2': 4, 'clip_low': 0.8266911263664067, 'clip_high': 1.1591099411136605}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,262] Trial 505 finished with value: 21048.32147979425 and parameters: {'n_lags': 10, 'alpha': 0.6586431447528597, 't2': 4, 'clip_low': 0.8641888316432704, 'clip_high': 1.1612104909993026}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,283] Trial 506 finished with value: 21079.452809148923 and parameters: {'n_lags': 8, 'alpha': 0.6804634628091775, 't2': 4, 'clip_low': 0.7937988245184353, 'clip_high': 1.1773477396916754}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,304] Trial 507 finished with value: 21047.61480016755 and parameters: {'n_lags': 9, 'alpha': 0.6499512357674734, 't2': 4, 'clip_low': 0.7504848342067003, 'clip_high': 1.1532608410792307}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,325] Trial 508 finished with value: 21048.02822135342 and parameters: {'n_lags': 9, 'alpha': 0.7008051520144087, 't2': 9, 'clip_low': 0.7175602804023957, 'clip_high': 1.1919660775178447}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,347] Trial 509 finished with value: 21046.445208569825 and parameters: {'n_lags': 9, 'alpha': 0.6856796585482817, 't2': 4, 'clip_low': 0.83388237072884, 'clip_high': 1.3017953755021405}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,368] Trial 510 finished with value: 21095.313092345186 and parameters: {'n_lags': 7, 'alpha': 0.6668813984712033, 't2': 4, 'clip_low': 0.8544854133156465, 'clip_high': 1.366760763547109}. Best is trial 294 with value: 21046.09057101842.
# [I 2025-09-30 02:04:56,389] Trial 511 finished with value: 21050.761404404315 and parameters: {'n_lags': 9, 'alpha': 0.7151671443962312, 't2': 4, 'clip_low': 0.932974315143755, 'clip_high': 1.166850342362636}. Best is trial 294 with value: 21046.09057101842.
# Best parameters: {'n_lags': 9, 'alpha': 0.6741577959564671, 't2': 4, 'clip_low': 0.8798137129337238, 'clip_high': 1.205522354649888}
# Submission saved to /Users/nikola/Python/KaggleCompetition/output/11_EWGM
